# %% [markdown]
# # 🌐 Base de Données de l'Étude

# %% [markdown]
# ## Phase 1: Récupération et Visualisation des Régions de France
#
# Ce code télécharge les données géographiques des régions françaises, calcule leurs centroïdes et affiche une carte. Les centroïdes sont extraits pour chaque région et stockés sous forme de triplets (region, longitude, latitude) pour une utilisation ultérieure.

# %%
#Installation des bibliothèques nécessaires pour la récupération et la représentation des données géographiques
# !pip install contextily && geopandas &&  topojson && py7zr && openpyxl && tqdm && s3fs && pandas && fiona && shapely && pyproj && rtree
# !pip install PyYAML xlrd && git+https://github.com/inseefrlab/cartiflette && git+https://github.com/inseeFrLab/cartiflette.git && openmeteo-requests
# !pip install requests-cache retry-requests 
# !pip install geopandas
# !pip install cartiflette
# Out:
# Requirement already satisfied: contextily in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.6.2)
# Requirement already satisfied: geopy in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (3.9.3)
# Requirement already satisfied: mercantile in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (11.0.0)
# Requirement already satisfied: rasterio in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (1.4.3)
# Requirement already satisfied: requests in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (1.4.2)
# Requirement already satisfied: xyzservices in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from contextily) (2024.9.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mercantile->contextily) (8.1.7)
# Requirement already satisfied: affine in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rasterio->contextily) (24.2.0)
# Requirement already satisfied: certifi in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rasterio->contextily) (2024.8.30)
# Requirement already satisfied: cligj>=0.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->contextily) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->contextily) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->contextily) (1.26.20)
# Requirement already satisfied: colorama in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=3.0->mercantile->contextily) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\nouts\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# 'geopandas' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# Requirement already satisfied: PyYAML in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (6.0.2)
# Requirement already satisfied: xlrd in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.0.1)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\nouts\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# 'git+https:' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# Requirement already satisfied: requests-cache in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.2.1)
# Requirement already satisfied: retry-requests in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.0.0)
# Requirement already satisfied: attrs>=21.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache) (4.3.6)
# Requirement already satisfied: requests>=2.22 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache) (2.32.3)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache) (1.4.3)
# Requirement already satisfied: urllib3>=1.25.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache) (1.26.20)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.22->requests-cache) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.22->requests-cache) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.22->requests-cache) (2024.8.30)
# Requirement already satisfied: six in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from url-normalize>=1.4->requests-cache) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\nouts\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: geopandas in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: packaging in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (2.2.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.4.0->geopandas) (2024.2)
# Requirement already satisfied: certifi in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.16.0)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\nouts\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: cartiflette in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.0.2)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (6.0.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.4 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.4.4)
# Requirement already satisfied: charset-normalizer<4.0.0,>=3.2.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (3.4.0)
# Requirement already satisfied: diskcache<6.0.0,>=5.6.3 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (5.6.3)
# Requirement already satisfied: fastexcel<0.12.0,>=0.11.6 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (0.11.6)
# Requirement already satisfied: fiona<2.0.0,>=1.9.4.post1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (1.10.1)
# Requirement already satisfied: geopandas<2.0.0,>=1.0.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.0.1)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (3.9.3)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (3.1.5)
# Requirement already satisfied: owslib<0.29.0,>=0.28.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (0.28.1)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (2.2.3)
# Requirement already satisfied: pebble<6.0.0,>=5.0.3 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (5.1.0)
# Requirement already satisfied: polars<2.0.0,>=1.8.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.17.1)
# Requirement already satisfied: py7zr<0.21.0,>=0.20.4 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (0.20.8)
# Requirement already satisfied: pyarrow<18.0.0,>=17.0.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (17.0.0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.0.1)
# Requirement already satisfied: python-magic-bin<0.5.0,>=0.4.14 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (0.4.14)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (2.32.3)
# Requirement already satisfied: requests-cache<2.0.0,>=1.1.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.2.1)
# Requirement already satisfied: retrying<2.0.0,>=1.3.4 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.3.4)
# Requirement already satisfied: s3fs<2024.0.0,>=2023.3.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (2023.12.2)
# Requirement already satisfied: topojson<2.0,>=1.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.9)
# Requirement already satisfied: unidecode<2.0.0,>=1.3.6 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.3.8)
# Requirement already satisfied: urllib3<2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (1.26.20)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartiflette) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fiona<2.0.0,>=1.9.4.post1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (24.2.0)
# Requirement already satisfied: certifi in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fiona<2.0.0,>=1.9.4.post1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (2024.8.30)
# Requirement already satisfied: click~=8.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fiona<2.0.0,>=1.9.4.post1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fiona<2.0.0,>=1.9.4.post1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fiona<2.0.0,>=1.9.4.post1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (0.7.2)
# Requirement already satisfied: boto3>=1.3.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (1.35.36)
# Requirement already satisfied: numpy>=1.22 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette) (2.1.3)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette) (0.10.0)
# Requirement already satisfied: packaging in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette) (24.2)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette) (3.7.0)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from geopandas<2.0.0,>=1.0.1->cartiflette) (2.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib<4.0.0,>=3.7.1->cartiflette) (2.9.0.post0)
# Requirement already satisfied: et-xmlfile in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openpyxl<4.0.0,>=3.1.5->cartiflette) (2.0.0)
# Requirement already satisfied: lxml in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from owslib<0.29.0,>=0.28.1->cartiflette) (5.3.0)
# Requirement already satisfied: pytz in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from owslib<0.29.0,>=0.28.1->cartiflette) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas<3.0.0,>=2.2.2->cartiflette) (2024.2)
# Requirement already satisfied: texttable in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (1.7.0)
# Requirement already satisfied: pycryptodomex>=3.16.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (3.21.0)
# Requirement already satisfied: pyzstd>=0.15.9 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (0.16.2)
# Requirement already satisfied: pyppmd<1.2.0,>=1.1.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (1.1.0)
# Requirement already satisfied: pybcj<1.1.0,>=1.0.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (1.0.2)
# Requirement already satisfied: multivolumefile>=0.2.3 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (0.2.3)
# Requirement already satisfied: inflate64<1.1.0,>=1.0.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (1.0.0)
# Requirement already satisfied: brotli>=1.1.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (1.1.0)
# Requirement already satisfied: psutil in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from py7zr<0.21.0,>=0.20.4->cartiflette) (6.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.2->cartiflette) (3.10)
# Requirement already satisfied: cattrs>=22.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache<2.0.0,>=1.1.0->cartiflette) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache<2.0.0,>=1.1.0->cartiflette) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-cache<2.0.0,>=1.1.0->cartiflette) (1.4.3)
# Requirement already satisfied: six>=1.7.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from retrying<2.0.0,>=1.3.4->cartiflette) (1.16.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette) (2.15.2)
# Requirement already satisfied: fsspec==2023.12.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette) (2023.12.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from s3fs<2024.0.0,>=2023.3.0->cartiflette) (3.11.10)
# Requirement already satisfied: botocore<1.35.37,>=1.35.16 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette) (1.35.36)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette) (1.17.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024.0.0,>=2023.3.0->cartiflette) (0.12.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs<2024.0.0,>=2023.3.0->cartiflette) (1.18.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3>=1.3.1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3>=1.3.1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (0.10.4)
# Requirement already satisfied: colorama in c:\users\nouts\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click~=8.0->fiona<2.0.0,>=1.9.4.post1->fiona[s3]<2.0.0,>=1.9.4.post1->cartiflette) (0.4.6)
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: C:\Users\nouts\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt

# %%
# Récupératoin des données 

from cartiflette import carti_download

france = carti_download(
    values=["France"],
    crs=4326,
    borders="REGION",
    vectorfile_format="geojson",
    simplification=50,
    filter_by="FRANCE_ENTIERE",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022,
)

# %%
france.head()
# Out:
#    INSEE_REG    PAYS        LIBELLE_REGION  POPULATION  \
# 0          1  France            Guadeloupe      384239
# 1          3  France                Guyane      281678
# 2          2  France            Martinique      364508
# 3          6  France               Mayotte      256518
# 4         84  France  Auvergne-Rhône-Alpes     8042936
#
#                              SOURCE  \
# 0  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 1  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 2  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 3  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 4  IGN:EXPRESS-COG-CARTO-TERRITOIRE
#
#                                             geometry
# 0  MULTIPOLYGON (((-61.62648 16.27275, -61.62658 ...
# 1  MULTIPOLYGON (((-51.6408 4.21282, -51.64144 4....
# 2  MULTIPOLYGON (((-60.93246 14.7306, -60.9326 14...
# 3  MULTIPOLYGON (((45.08357 -12.96139, 45.08547 -...
# 4  POLYGON ((6.06386 46.41639, 6.06267 46.4168, 6...

# %%
print(france.crs)
# Out:
# EPSG:4326

# %%
#REPRESENTATION 

if france.crs.to_string() != "EPSG:3857":
    france = france.to_crs(epsg=3857)
#Les  limites de la carte
xmin, xmax = -0.75e6, 1.2e6  # Convertir les limites en mètres (EPSG:3857)
ymin, ymax = 5e6, 6.75e6

#Ploting
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
france.plot(ax=ax)
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
plt.title("Les régions de la France", fontsize=10)
plt.show()

# %%
# Ajout d'un fond de carte pour un meilleur contexte géographique
fig, ax = plt.subplots(1, 1, figsize=(6, 6)) 
france.plot(ax=ax, edgecolor='black', linewidth=1, alpha=0.3)
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
# 
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, crs=france.crs)
#
plt.title("Les régions de la France", fontsize=14, fontweight='bold')
ax.axis('off') 

plt.tight_layout() 
plt.show()

# %%
#Représentation des centroides 
france['centroid'] = france.geometry.centroid
france['longitude'] = france.centroid.x
france['latitude'] = france.centroid.y
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
france.plot(ax=ax, edgecolor='black', linewidth=1, alpha=0.3, color='lightblue')
ax.scatter(france['longitude'], france['latitude'], color='red', s=20, label='Centroides')
ax.set_xlim(xmin, xmax)
ax.set_ylim(ymin, ymax)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik, crs=france.crs)
plt.title("Les régions de la France avec leurs centroides", fontsize=14, fontweight='bold')
ax.axis('off')
ax.legend()
plt.tight_layout()
plt.show()

# %%
# Calcul des longitudes et latitudes 
france = france.to_crs(epsg=4326)
france['longitude'] = france.geometry.centroid.x
france['latitude'] = france.geometry.centroid.y
print(france[['LIBELLE_REGION', 'longitude', 'latitude']])
# Out:
#                 LIBELLE_REGION  longitude   latitude
# 0                   Guadeloupe -61.539833  16.197646
# 1                       Guyane -53.239940   3.915167
# 2                   Martinique -61.019379  14.654871
# 3                      Mayotte  45.147435 -12.820617
# 4         Auvergne-Rhône-Alpes   4.536119  45.514642
# 5                    Occitanie   2.143923  43.702500
# 6                     Bretagne  -2.841463  48.177549
# 7           Nouvelle-Aquitaine   0.212719  45.206040
# 8                    Normandie   0.110932  49.120067
# 9   Provence-Alpes-Côte d'Azur   6.061005  43.958789
# 10            Pays de la Loire  -0.816786  47.478104
# 11                   Grand Est   5.613112  48.688977
# 12     Bourgogne-Franche-Comté   4.806857  47.234282
# 13               Île-de-France   2.503401  48.709316
# 14         Centre-Val de Loire   1.684391  47.484775
# 15             Hauts-de-France   2.771303  49.969594
# 16                       Corse   9.106152  42.151511
# 17                  La Réunion  55.532509 -21.133203
# C:\Users\nouts\AppData\Local\Temp\ipykernel_13724\2487130668.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   france['longitude'] = france.geometry.centroid.x
# C:\Users\nouts\AppData\Local\Temp\ipykernel_13724\2487130668.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   france['latitude'] = france.geometry.centroid.y

# %%
france.head()
# Out:
#    INSEE_REG    PAYS        LIBELLE_REGION  POPULATION  \
# 0          1  France            Guadeloupe      384239
# 1          3  France                Guyane      281678
# 2          2  France            Martinique      364508
# 3          6  France               Mayotte      256518
# 4         84  France  Auvergne-Rhône-Alpes     8042936
#
#                              SOURCE  \
# 0  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 1  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 2  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 3  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 4  IGN:EXPRESS-COG-CARTO-TERRITOIRE
#
#                                             geometry  \
# 0  MULTIPOLYGON (((-61.62648 16.27275, -61.62658 ...
# 1  MULTIPOLYGON (((-51.6408 4.21282, -51.64144 4....
# 2  MULTIPOLYGON (((-60.93246 14.7306, -60.9326 14...
# 3  MULTIPOLYGON (((45.08357 -12.96139, 45.08547 -...
# 4  POLYGON ((6.06386 46.41639, 6.06267 46.4168, 6...
#
#                            centroid  longitude   latitude
# 0  POINT (-6850582.542 1827642.261) -61.539833  16.197646
# 1    POINT (-5926644.81 436331.726) -53.239940   3.915167
# 2  POINT (-6792650.367 1649468.223) -61.019379  14.654871
# 3  POINT (5025789.843 -1439250.269)  45.147435 -12.820617
# 4     POINT (504837.95 5704315.458)   4.536119  45.514642

# %%
# Création de la liste de triplets (région, longitude, latitude)
region_centroides = []
for index, row in france.iterrows():
    region = row['LIBELLE_REGION']  # Nom de la région
    longitude = row['longitude']  # Longitude du centroïde
    latitude = row['latitude']    # Latitude du centroïde
    region_centroides.append((region, longitude, latitude)) # Ajout du triplet à la liste
region_centroides
# Out:
# [('Guadeloupe', -61.53983304107784, 16.197645826552904),
#  ('Guyane', -53.23993971851178, 3.915166862499844),
#  ('Martinique', -61.019378740773654, 14.654870858984358),
#  ('Mayotte', 45.14743542382146, -12.820616875536656),
#  ('Auvergne-Rhône-Alpes', 4.536118586333609, 45.51464202656834),
#  ('Occitanie', 2.143922833937654, 43.70250024549978),
#  ('Bretagne', -2.841462676465886, 48.17754922086023),
#  ('Nouvelle-Aquitaine', 0.21271860548694332, 45.2060395396088),
#  ('Normandie', 0.11093239896467046, 49.12006667987373),
#  ("Provence-Alpes-Côte d'Azur", 6.061004522552231, 43.95878857291765),
#  ('Pays de la Loire', -0.81678598261894, 47.47810354487287),
#  ('Grand Est', 5.613112231600144, 48.68897740160863),
#  ('Bourgogne-Franche-Comté', 4.806856915301157, 47.2342819451994),
#  ('Île-de-France', 2.503401392552759, 48.70931550109074),
#  ('Centre-Val de Loire', 1.684391322381998, 47.48477508284454),
#  ('Hauts-de-France', 2.7713028658475474, 49.969593961262426),
#  ('Corse', 9.106151755156151, 42.15151137562012),
#  ('La Réunion', 55.53250880056539, -21.133202961171154)]

# %% [markdown]
# # Phase 2: Collecte des Données de Qualité de l'Air
#
# Ce script collecte des **données horaires de qualité de l'air** via l'API Open-Meteo pour différentes régions.
# Il récupère les polluants clés (**PM10**, **PM2.5**, **CO**, **NO₂**, **SO₂**, **Ozone**)
# et les organise dans un tableau structuré.
#
# ---
#
# ## **Fonctionnalités**
# - Utilisation d'un **cache** et de **répétitions automatiques** pour des requêtes fiables.
# - Organisation des données dans des **DataFrames pandas**.
# - Ajout d'une colonne pour **extraire les dates** sans les heures.
# - Fusion des données pour une **analyse centralisée**.

# %%
import openmeteo_requests
import requests_cache
import pandas as pd
from retry_requests import retry
from openmeteo_requests import Client


# Création d'une session avec cache
cache_session = requests_cache.CachedSession('.cache', expire_after=3600)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = Client(session=retry_session)

# Création d'un dictionnaire pour stocker les DataFrames
region_dataframes = {}

# Boucle pour récupérer les données pour chaque région
for region, longitude, latitude in region_centroides:
    try:
        url = "https://air-quality-api.open-meteo.com/v1/air-quality"
        params = {
            "latitude": latitude,
            "longitude": longitude,
            "current": ["european_aqi", "us_aqi"],
            "hourly": ["pm10", "pm2_5", "carbon_monoxide", "carbon_dioxide", "nitrogen_dioxide", "sulphur_dioxide", "ozone"],
            "start_date": "2023-01-01",
            "end_date": "2024-11-30"
        }

        responses = openmeteo.weather_api(url, params=params)
        response = responses[0]  # Première réponse, si plusieurs localisations

        # Récupération des données horaires
        hourly = response.Hourly()
        hourly_data = {
            "date": pd.date_range(
                start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=hourly.Interval()),
                inclusive="left"
            ),
            "region": [region] * len(pd.date_range(
                start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=hourly.Interval()),
                inclusive="left"
            )),
            "pm10": hourly.Variables(0).ValuesAsNumpy(),
            "pm2_5": hourly.Variables(1).ValuesAsNumpy(),
            "carbon_monoxide": hourly.Variables(2).ValuesAsNumpy(),
            "carbon_dioxide": hourly.Variables(3).ValuesAsNumpy(),
            "nitrogen_dioxide": hourly.Variables(4).ValuesAsNumpy(),
            "sulphur_dioxide": hourly.Variables(5).ValuesAsNumpy(),
            "ozone": hourly.Variables(6).ValuesAsNumpy()
        }

        # Stockage du DataFrame dans le dictionnaire
        region_dataframes[region] = pd.DataFrame(data=hourly_data)

    except Exception as e:
        print(f"Erreur lors de la récupération des données pour {region}: {e}")

# Concaténation tous les DataFrames
combined_dataframe_air = pd.concat(region_dataframes.values(), ignore_index=True)
combined_dataframe_air['date'] = pd.to_datetime(combined_dataframe_air['date'])
# Création d'une nouvelle colonne 'day' contenant uniquement la date (sans l'heure)
#combined_dataframe_air['day'] = combined_dataframe_air['date'].dt.date
combined_dataframe_air.insert(1,"day",combined_dataframe_air["date"].dt.date)

# %%
combined_dataframe_air
# Out:
#                             date         day      region       pm10  pm2_5  \
# 0      2023-01-01 00:00:00+00:00  2023-01-01  Guadeloupe  20.500000   11.3
# 1      2023-01-01 01:00:00+00:00  2023-01-01  Guadeloupe  21.700001   11.9
# 2      2023-01-01 02:00:00+00:00  2023-01-01  Guadeloupe  21.799999   12.0
# 3      2023-01-01 03:00:00+00:00  2023-01-01  Guadeloupe  20.700001   11.4
# 4      2023-01-01 04:00:00+00:00  2023-01-01  Guadeloupe  19.400000   10.7
# ...                          ...         ...         ...        ...    ...
# 302395 2024-11-30 19:00:00+00:00  2024-11-30  La Réunion  10.000000    7.1
# 302396 2024-11-30 20:00:00+00:00  2024-11-30  La Réunion   9.800000    7.1
# 302397 2024-11-30 21:00:00+00:00  2024-11-30  La Réunion   9.700000    7.0
# 302398 2024-11-30 22:00:00+00:00  2024-11-30  La Réunion   9.500000    6.9
# 302399 2024-11-30 23:00:00+00:00  2024-11-30  La Réunion   9.500000    7.0
#
#         carbon_monoxide  carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  \
# 0                  89.0             NaN              3.70             0.30
# 1                  89.0             NaN              3.45             0.30
# 2                  88.0             NaN              3.15             0.25
# 3                  88.0             NaN              2.60             0.25
# 4                  88.0             NaN              2.10             0.25
# ...                 ...             ...               ...              ...
# 302395            100.0           459.0              3.60             2.50
# 302396             95.0           455.0              4.20             2.30
# 302397             91.0           453.0              4.50             2.20
# 302398             90.0           455.0              4.40             2.10
# 302399             89.0           459.0              4.10             2.10
#
#         ozone
# 0        62.0
# 1        62.0
# 2        63.0
# 3        64.0
# 4        64.0
# ...       ...
# 302395   56.0
# 302396   52.0
# 302397   49.0
# 302398   47.0
# 302399   46.0
#
# [302400 rows x 10 columns]

# %%
# Création d'une session avec cache
cache_session = requests_cache.CachedSession('.cache', expire_after=3600)
retry_session = retry(cache_session, retries=5, backoff_factor=0.2)
openmeteo = Client(session=retry_session)

# Création d'un dictionnaire pour stocker les DataFrames
region_dataframes = {}

# Boucle pour récupérer les données pour chaque région
for region, longitude, latitude in region_centroides:
    try:
        url = "https://archive-api.open-meteo.com/v1/archive"
        params = {
            "latitude": latitude,
            "longitude": longitude,
            "hourly": ["temperature_2m", "relative_humidity_2m", "precipitation", "surface_pressure", "wind_speed_10m", "soil_temperature_0_to_7cm", "soil_moisture_0_to_7cm"],
            "start_date": "2023-01-01",
            "end_date": "2024-11-30"
        }

        responses = openmeteo.weather_api(url, params=params)
        response = responses[0]  # Première réponse, si plusieurs localisations

        # Récupération des données horaires
        hourly = response.Hourly()
        hourly_data = {
            "date": pd.date_range(
                start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=hourly.Interval()),
                inclusive="left"
            ),
            "region": [region] * len(pd.date_range(
                start=pd.to_datetime(hourly.Time(), unit="s", utc=True),
                end=pd.to_datetime(hourly.TimeEnd(), unit="s", utc=True),
                freq=pd.Timedelta(seconds=hourly.Interval()),
                inclusive="left"
            )),
            "temperature_2m": hourly.Variables(0).ValuesAsNumpy(),
            "relative_humidity_2m": hourly.Variables(1).ValuesAsNumpy(),
            "precipitation": hourly.Variables(2).ValuesAsNumpy(),
            "surface_pressure": hourly.Variables(3).ValuesAsNumpy(),
            "wind_speed_10m": hourly.Variables(4).ValuesAsNumpy(),
            "soil_temperature_0_to_7cm": hourly.Variables(5).ValuesAsNumpy(),
            "soil_moisture_0_to_7cm": hourly.Variables(6).ValuesAsNumpy(),
            
        }

        # Stockage du DataFrame dans le dictionnaire
        region_dataframes[region] = pd.DataFrame(data=hourly_data)

    except Exception as e:
        print(f"Erreur lors de la récupération des données pour {region}: {e}")
        
    # Concaténation tous les DataFrames
combined_dataframe_climat = pd.concat(region_dataframes.values(), ignore_index=True)
combined_dataframe_climat = combined_dataframe_climat.drop(columns=["region","date"])

# %%
df=pd.concat([combined_dataframe_air,combined_dataframe_climat],axis=1)
df
# Out:
#                             date         day      region       pm10  pm2_5  \
# 0      2023-01-01 00:00:00+00:00  2023-01-01  Guadeloupe  20.500000   11.3
# 1      2023-01-01 01:00:00+00:00  2023-01-01  Guadeloupe  21.700001   11.9
# 2      2023-01-01 02:00:00+00:00  2023-01-01  Guadeloupe  21.799999   12.0
# 3      2023-01-01 03:00:00+00:00  2023-01-01  Guadeloupe  20.700001   11.4
# 4      2023-01-01 04:00:00+00:00  2023-01-01  Guadeloupe  19.400000   10.7
# ...                          ...         ...         ...        ...    ...
# 302395 2024-11-30 19:00:00+00:00  2024-11-30  La Réunion  10.000000    7.1
# 302396 2024-11-30 20:00:00+00:00  2024-11-30  La Réunion   9.800000    7.1
# 302397 2024-11-30 21:00:00+00:00  2024-11-30  La Réunion   9.700000    7.0
# 302398 2024-11-30 22:00:00+00:00  2024-11-30  La Réunion   9.500000    6.9
# 302399 2024-11-30 23:00:00+00:00  2024-11-30  La Réunion   9.500000    7.0
#
#         carbon_monoxide  carbon_dioxide  nitrogen_dioxide  sulphur_dioxide  \
# 0                  89.0             NaN              3.70             0.30
# 1                  89.0             NaN              3.45             0.30
# 2                  88.0             NaN              3.15             0.25
# 3                  88.0             NaN              2.60             0.25
# 4                  88.0             NaN              2.10             0.25
# ...                 ...             ...               ...              ...
# 302395            100.0           459.0              3.60             2.50
# 302396             95.0           455.0              4.20             2.30
# 302397             91.0           453.0              4.50             2.20
# 302398             90.0           455.0              4.40             2.10
# 302399             89.0           459.0              4.10             2.10
#
#         ozone  temperature_2m  relative_humidity_2m  precipitation  \
# 0        62.0       23.770000             84.863304            0.0
# 1        62.0       23.719999             85.643173            0.0
# 2        63.0       23.520000             86.947586            0.0
# 3        64.0       23.270000             88.269188            0.0
# 4        64.0       22.469999             94.082932            0.2
# ...       ...             ...                   ...            ...
# 302395   56.0       10.291500             93.833534            0.0
# 302396   52.0        9.891500             93.814590            0.0
# 302397   49.0        9.391500             97.342743            0.0
# 302398   47.0        8.891500             99.663048            0.0
# 302399   46.0        9.091500             99.663582            0.0
#
#         surface_pressure  wind_speed_10m  soil_temperature_0_to_7cm  \
# 0            1017.400024        9.422101                  24.020000
# 1            1017.599976        9.885262                  23.670000
# 2            1017.700012        9.720000                  23.420000
# 3            1017.400024        7.559999                  23.219999
# 4            1017.299988        8.825508                  23.020000
# ...                  ...             ...                        ...
# 302395        824.523071        3.617955                  12.941500
# 302396        823.957458        3.847960                  12.441500
# 302397        823.007019        3.065289                  11.991500
# 302398        822.137085        2.979530                  11.591500
# 302399        821.774109        3.710795                  11.341500
#
#         soil_moisture_0_to_7cm
# 0                        0.501
# 1                        0.499
# 2                        0.498
# 3                        0.497
# 4                        0.497
# ...                        ...
# 302395                   0.235
# 302396                   0.235
# 302397                   0.234
# 302398                   0.234
# 302399                   0.234
#
# [302400 rows x 17 columns]

# %% [markdown]
# ## 🌍 Phase 3: Calcul de l'Indice ATMO
#
# L'**indice ATMO** évalue la qualité de l'air en France en se basant sur **cinq polluants** : **PM10**, **PM2.5**, **NO₂**, **O₃** et **SO₂**.
#
# ### 🛠️ **Méthode de Calcul**
# 1. **Sous-indices** :
#    Chaque polluant reçoit un **sous-indice** en fonction de sa **concentration** moyenne journalière (en µg/m³). Les seuils sont définis par des grilles précises :
#
#    | **Sous-indice** | **PM10 (µg/m³)** | **PM2.5 (µg/m³)** | **NO₂ (µg/m³)** | **O₃ (µg/m³)** | **SO₂ (µg/m³)** |
#    |-----------------|------------------|------------------|----------------|---------------|----------------|
#    | 1 (Très bon)   | 0 - 6            | 0 - 4            | 0 - 29         | 0 - 29        | 0 - 39         |
#    | 2              | 7 - 13           | 5 - 7            | 30 - 54        | 30 - 54       | 40 - 79        |
#    | 3              | 14 - 20          | 8 - 10           | 55 - 84        | 55 - 79       | 80 - 119       |
#    | 4              | 21 - 27          | 11 - 12          | 85 - 109       | 80 - 104      | 120 - 159      |
#    | 5              | 28 - 34          | 13 - 15          | 110 - 134      | 105 - 129     | 160 - 199      |
#    | 6              | 35 - 41          | 16 - 17          | 135 - 164      | 130 - 149     | 200 - 249      |
#    | 7              | 42 - 49          | 18 - 19          | 165 - 199      | 150 - 179     | 250 - 299      |
#    | 8              | 50 - 64          | 20 - 22          | 200 - 274      | 180 - 209     | 300 - 399      |
#    | 9              | 65 - 79          | 23 - 25          | 275 - 399      | 210 - 239     | 400 - 499      |
#    | 10 (Très mauvais) | ≥ 80          | ≥ 26             | ≥ 400          | ≥ 240         | ≥ 500          |
#
# 2. **Indice Final** :
#    L'indice ATMO correspond au **maximum** des sous-indices obtenus pour chaque polluant mesuré dans la journée.
#
# ---
#
# ### 📊 **Échelle des Sous-Indices**
# | **Indice ATMO** | **Niveau**       | **Couleur**        |
# |-----------------|------------------|--------------------|
# | 1-2            | Très bon         | 🟢 Vert clair      |
# | 3-4            | Bon              | 🟢 Vert            |
# | 5              | Moyen            | 🟡 Jaune           |
# | 6-7            | Médiocre         | 🟠 Orange          |
# | 8-9            | Mauvais          | 🔴 Rouge           |
# | 10             | Très mauvais     | 🟣 Violet          |
#
# ---
#
# ### 🔗 **Source Officielle**
# [L'indice ATMO - Atmo France](https://www.atmo-france.org/article/lindice-atmo)

# %%
import pandas as pd

# Convert 'date' and 'day' columns to datetime
df['date'] = pd.to_datetime(df['date'])
df['day'] = pd.to_datetime(df['day'])

# Sort data by 'region', 'day', and 'date'
df = df.sort_values(by=['region', 'day', 'date'])

# Define functions to compute sub-indices for each pollutant
def get_subindex_pm10(value):
    if value <= 6: return 1
    elif value <= 13: return 2
    elif value <= 20: return 3
    elif value <= 27: return 4
    elif value <= 34: return 5
    elif value <= 41: return 6
    elif value <= 49: return 7
    elif value <= 64: return 8
    elif value <= 79: return 9
    else: return 10

def get_subindex_no2(value):
    if value <= 29: return 1
    elif value <= 54: return 2
    elif value <= 84: return 3
    elif value <= 109: return 4
    elif value <= 134: return 5
    elif value <= 164: return 6
    elif value <= 199: return 7
    elif value <= 274: return 8
    elif value <= 399: return 9
    else: return 10

def get_subindex_o3(value):
    if value <= 29: return 1
    elif value <= 54: return 2
    elif value <= 79: return 3
    elif value <= 104: return 4
    elif value <= 129: return 5
    elif value <= 149: return 6
    elif value <= 179: return 7
    elif value <= 209: return 8
    elif value <= 239: return 9
    else: return 10

def get_subindex_so2(value):
    if value <= 39: return 1
    elif value <= 79: return 2
    elif value <= 119: return 3
    elif value <= 159: return 4
    elif value <= 199: return 5
    elif value <= 249: return 6
    elif value <= 299: return 7
    elif value <= 399: return 8
    elif value <= 499: return 9
    else: return 10

# Calcul des moyennes journalières pour toutes les variables
daily_data = df.groupby(['day', 'region']).agg({
    'pm10': 'mean',
    'nitrogen_dioxide': 'mean',
    'ozone': lambda x: x.rolling(8, min_periods=1).mean().max(),  # Max sur 8h glissantes
    'sulphur_dioxide': 'mean',
    **{col: 'mean' for col in df.columns if col not in ['date', 'day', 'region', 'pm10', 'nitrogen_dioxide', 'ozone', 'sulphur_dioxide']}
}).reset_index()

# Calculer les sous-indices
daily_data['subindex_pm10'] = daily_data['pm10'].apply(get_subindex_pm10)
daily_data['subindex_no2'] = daily_data['nitrogen_dioxide'].apply(get_subindex_no2)
daily_data['subindex_o3'] = daily_data['ozone'].apply(get_subindex_o3)
daily_data['subindex_so2'] = daily_data['sulphur_dioxide'].apply(get_subindex_so2)

# Calcul de l'indice Atmo final
daily_data['indice_atmo'] = daily_data[['subindex_pm10', 'subindex_no2', 'subindex_o3', 'subindex_so2']].max(axis=1)

# Fusionner avec le DataFrame original pour conserver uniquement les colonnes de df
final_df = df[['day', 'region']].drop_duplicates().merge(daily_data, on=['day', 'region'], how='left')

# Afficher le résultat final
final_df
# Out:
#              day                region       pm10  nitrogen_dioxide   ozone  \
# 0     2023-01-01  Auvergne-Rhône-Alpes  14.954166          3.475000  65.125
# 1     2023-01-02  Auvergne-Rhône-Alpes  14.316667          5.904167  71.000
# 2     2023-01-03  Auvergne-Rhône-Alpes   8.666667         11.420834  53.750
# 3     2023-01-04  Auvergne-Rhône-Alpes  15.504167         17.929167  37.875
# 4     2023-01-05  Auvergne-Rhône-Alpes  11.616666         12.416667  44.375
# ...          ...                   ...        ...               ...     ...
# 12595 2024-11-26         Île-de-France  12.691667         13.220833  57.375
# 12596 2024-11-27         Île-de-France   7.362500         11.762500  62.750
# 12597 2024-11-28         Île-de-France  14.870833         19.445833  45.000
# 12598 2024-11-29         Île-de-France  14.041667         12.087501  53.250
# 12599 2024-11-30         Île-de-France  20.308332         17.637501  37.000
#
#        sulphur_dioxide      pm2_5  carbon_monoxide  carbon_dioxide  \
# 0             0.837500   7.858334       118.791664             NaN
# 1             0.933333   7.962500       136.208328             NaN
# 2             0.729167   6.525000       170.833328             NaN
# 3             1.075000  11.441667       194.125000             NaN
# 4             0.725000   9.070833       170.000000             NaN
# ...                ...        ...              ...             ...
# 12595         0.916667   8.512500       193.083328      449.125000
# 12596         0.775000   5.725000       171.625000      446.583344
# 12597         1.537500  12.295834       227.041672      459.791656
# 12598         0.920833  11.537499       207.750000      450.000000
# 12599         1.420833  17.858334       278.291656      463.250000
#
#        temperature_2m  ...  precipitation  surface_pressure  wind_speed_10m  \
# 0           11.954083  ...       0.000000        964.791809       23.574928
# 1           10.583250  ...       0.550000        965.794250       15.330505
# 2            6.727000  ...       0.125000        971.449707        5.034335
# 3            5.220750  ...       0.000000        972.121399        4.557892
# 4            7.531167  ...       0.016667        968.975586        5.073804
# ...               ...  ...            ...               ...             ...
# 12595        8.658334  ...       0.108333       1014.152649       11.292778
# 12596       10.439584  ...       0.254167       1012.352295       17.599253
# 12597        6.358334  ...       0.004167       1022.028015        6.830119
# 12598        3.558333  ...       0.000000       1023.345276        9.613878
# 12599        2.770833  ...       0.000000       1021.944885        4.865319
#
#        soil_temperature_0_to_7cm  soil_moisture_0_to_7cm  subindex_pm10  \
# 0                      10.964500                0.365333              3
# 1                      10.477000                0.384500              3
# 2                       7.685333                0.411792              2
# 3                       5.731167                0.387917              3
# 4                       7.256167                0.384125              2
# ...                          ...                     ...            ...
# 12595                   8.785417                0.402167              2
# 12596                   9.512501                0.395292              2
# 12597                   7.887500                0.391583              3
# 12598                   4.350000                0.386667              3
# 12599                   3.306250                0.376583              4
#
#        subindex_no2  subindex_o3  subindex_so2  indice_atmo
# 0                 1            3             1            3
# 1                 1            3             1            3
# 2                 1            2             1            2
# 3                 1            2             1            3
# 4                 1            2             1            2
# ...             ...          ...           ...          ...
# 12595             1            3             1            3
# 12596             1            3             1            3
# 12597             1            2             1            3
# 12598             1            2             1            3
# 12599             1            2             1            4
#
# [12600 rows x 21 columns]

# %% [markdown]
# ## Analyse exploratoire
